# %%
# !pip install pandas numpy matplotlib pyarrow
# !conda install pandas numpy matplotlib

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import os
import pyarrow.parquet as pq

# %%
os.getcwd()
# Out:
# 'd:\\Sem5\\AppliedCreditRiskModelling\\git_folder'

# %%
data1 = pd.read_csv("./data_large/1/german_credit_data.csv", index_col=0)
data1.head(5)
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little              NaN           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    Duration              Purpose
# 0         6             radio/TV
# 1        48             radio/TV
# 2        12            education
# 3        42  furniture/equipment
# 4        24                  car

# %%
data2 = pd.read_csv("./data_large/2/credit_risk_dataset.csv")
data2.head(5)
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# ...

# %%
data3 = pd.read_csv("./data_large/3/loan/loan.csv")
data3.head(5)
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_26132\2951032171.py:1: DtypeWarning: Columns (19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   data3 = pd.read_csv("./data_large/3/loan/loan.csv")
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade  ... total_bal_il il_util  \
# 0     10.65       162.87     B        B2  ...          NaN     NaN
# 1     15.27        59.83     C        C4  ...          NaN     NaN
# 2     15.96        84.33     C        C5  ...          NaN     NaN
# ...

# %%
data4_1 = pd.read_csv("./data_large/4/customer_data.csv")
display(data4_1.head(5))

data4_2 = pd.read_csv("./data_large/4/payment_data.csv")
display(data4_2.head(5))
# Out:
#    label        id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  \
# 0      1  54982665      5  1245.5      3   77000.0      2     15      5
# 1      0  59004779      4  1277.0      1  113000.0      2      8     -1
# 2      0  58990862      7  1298.0      1  110000.0      2     11     -1
# 3      1  58995168      7  1335.5      1  151000.0      2     11      5
# 4      0  54987320      7     NaN      2   59000.0      2     11      5
#
#    fea_8  fea_9  fea_10      fea_11
# 0    109      5  151300  244.948974
# 1    100      3  341759  207.173840
# 2    101      5   72001    1.000000
# 3    110      3   60084    1.000000
# 4    108      4  450081  197.403141
#          id  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  prod_code  \
# 0  58987402       0       0       0        0           1         10
# 1  58995151       0       0       0        0           1          5
# 2  58997200       0       0       0        0           2          5
# ...

# %%
data5 = pd.read_csv("./data_large/5/original.csv")
data5.head(5)
# Out:
#    clientid        income        age         loan  default
# 0         1  66155.925095  59.017015  8106.532131        0
# 1         2  34415.153966  48.117153  6564.745018        0
# 2         3  57317.170063  63.108049  8020.953296        0
# 3         4  42709.534201  45.751972  6103.642260        0
# 4         5  66952.688845  18.584336  8770.099235        1

# %%
data6 = pd.read_csv("./data_large/6/data.csv")
data6.head(5)
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_26132\3407108509.py:1: DtypeWarning: Columns (17,45,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   data6 = pd.read_csv("./data_large/6/data.csv")
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade sub_grade  ... il_util open_rv_12m open_rv_24m  \
# 0     10.65       162.87     B        B2  ...     NaN         NaN         NaN
# 1     15.27        59.83     C        C4  ...     NaN         NaN         NaN
# ...

# %%
data7_1 = pd.read_csv("./data_large/7/application_record.csv")
display(data7_1.head(5))

data7_2 = pd.read_csv("./data_large/7/credit_record.csv")
display(data7_2.head(5))
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)


data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)

data8_1 = pq.read_table("./data_large/8/train_applprev_1_0.parquet")
data8_1 = data8_1.to_pandas()
data8_1.head(5)
# Out:
#    case_id  actualdpd_943P  annuity_853A approvaldate_319D  \
# 0        2             0.0         640.2              None
# 1        2             0.0        1682.4              None
# 2        3             0.0        6140.0              None
# 3        4             0.0        2556.6              None
# 4        5             0.0           NaN              None
#
#    byoccupationinc_3656910L cancelreason_3545846M  childnum_21L  \
# 0                       NaN              a55475b1           0.0
# 1                       NaN              a55475b1           0.0
# 2                       NaN           P94_109_143           NaN
# 3                       NaN             P24_27_36           NaN
# 4                       NaN           P85_114_140           NaN
#
#   creationdate_885D  credacc_actualbalance_314A  credacc_credlmt_575A  ...  \
# 0        2013-04-03                         NaN                   0.0  ...
# ...
